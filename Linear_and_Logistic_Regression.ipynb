# %% [markdown]
# **Temperature vs Humidity Linear Regression**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('/content/SeoulBikeData - SeoulBikeData.csv')
df=df.rename(columns={'Temperature(蚓)':"Temperature"})
df_binary = df[['Temperature', 'Humidity(%)']]

# Taking only the selected two attributes from the dataset
df_binary.columns = ['Temp', 'Humidity']

df_binary.head()
# Out:
#    Temp  Humidity
# 0  -5.2        37
# 1  -5.5        38
# 2  -6.0        39
# 3  -6.2        40
# 4  -6.0        36

# %%
df_binary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Temp      8760 non-null   float64
#  1   Humidity  8760 non-null   int64
# dtypes: float64(1), int64(1)
# memory usage: 137.0 KB

# %%
#plotting the Scatter plot to check relationship between SLength and SWidth
sns.lmplot(x ="Temp", y ="Humidity", data = df_binary, order = 2,ci=None) ##plot data wit overlaid rgression lines

# %%
X = np.array(df_binary['Temp']).reshape(-1, 1)
y = np.array(df_binary['Humidity']).reshape(-1, 1)

# Splitting the data into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)


regr = LinearRegression()

regr.fit(X_train, y_train)
print(regr.score(X_test, y_test))
# Out:
# 0.018617825825712142

# %%
y_pred = regr.predict(X_test)
plt.scatter(X_test, y_test, color ='b')
plt.plot(X_test, y_pred, color ='k')

plt.show()
# Data scatter of predicted values

# %% [markdown]
# **Temperature vs Windspeed Linear Regression**

# %%
df_binary = df[['Temperature', 'Wind speed (m/s)']]

# Taking only the selected two attributes from the dataset
df_binary.columns = ['Temp', 'Wind speed (m/s)']

df_binary.head()
# Out:
#    Temp  Wind speed (m/s)
# 0  -5.2               2.2
# 1  -5.5               0.8
# 2  -6.0               1.0
# 3  -6.2               0.9
# 4  -6.0               2.3

# %%
df_binary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Temp              8760 non-null   float64
#  1   Wind speed (m/s)  8760 non-null   float64
# dtypes: float64(2)
# memory usage: 137.0 KB

# %%
#plotting the Scatter plot to check relationship between SLength and SWidth
sns.lmplot(x ="Temp", y ="Wind speed (m/s)", data = df_binary, order = 2,ci=None) ##plot data wit overlaid rgression lines

# %%
X = np.array(df_binary['Temp']).reshape(-1, 1)
y = np.array(df_binary['Wind speed (m/s)']).reshape(-1, 1)

# Splitting the data into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)


regr = LinearRegression()

regr.fit(X_train, y_train)
print(regr.score(X_test, y_test))
# Out:
# -0.0011579845886671158

# %%
y_pred = regr.predict(X_test)
plt.scatter(X_test, y_test, color ='r')
plt.plot(X_test, y_pred, color ='k')

plt.show()
# Data scatter of predicted values

# %% [markdown]
# **Temperature vs Visibility Linear Regression**

# %%
df_binary = df[['Temperature', 'Visibility (10m)']]

# Taking only the selected two attributes from the dataset
df_binary.columns = ['Temp', 'Visibility (10m)']

df_binary.head()
# Out:
#    Temp  Visibility (10m)
# 0  -5.2              2000
# 1  -5.5              2000
# 2  -6.0              2000
# 3  -6.2              2000
# 4  -6.0              2000

# %%
df_binary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Temp              8760 non-null   float64
#  1   Visibility (10m)  8760 non-null   int64
# dtypes: float64(1), int64(1)
# memory usage: 137.0 KB

# %%
#plotting the Scatter plot to check relationship between SLength and SWidth
sns.lmplot(x ="Temp", y ="Visibility (10m)", data = df_binary, order = 2,ci=None) ##plot data wit overlaid rgression lines

# %%
X = np.array(df_binary['Temp']).reshape(-1, 1)
y = np.array(df_binary['Visibility (10m)']).reshape(-1, 1)

# Splitting the data into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)


regr = LinearRegression()

regr.fit(X_train, y_train)
print(regr.score(X_test, y_test))
# Out:
# 0.0015075067676318943

# %%
y_pred = regr.predict(X_test)
plt.scatter(X_test, y_test, color ='y')
plt.plot(X_test, y_pred, color ='r')

plt.show()
# Data scatter of predicted values

# %% [markdown]
# **Temperature vs Dew point Temperature Linear Regression**

# %%
df=df.rename(columns={'Dew point temperature(蚓)':"Dew Temperature"})
df_binary = df[['Temperature', 'Dew Temperature']]

# Taking only the selected two attributes from the dataset
df_binary.columns = ['Temp', 'Dew Temperature']

df_binary.head()
# Out:
#    Temp  Dew Temperature
# 0  -5.2            -17.6
# 1  -5.5            -17.6
# 2  -6.0            -17.7
# 3  -6.2            -17.6
# 4  -6.0            -18.6

# %%
df_binary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Temp             8760 non-null   float64
#  1   Dew Temperature  8760 non-null   float64
# dtypes: float64(2)
# memory usage: 137.0 KB

# %%
#plotting the Scatter plot to check relationship between SLength and SWidth
sns.lmplot(x ="Temp", y ="Dew Temperature", data = df_binary, order = 2,ci=None) ##plot data wit overlaid rgression lines

# %%
X = np.array(df_binary['Temp']).reshape(-1, 1)
y = np.array(df_binary['Dew Temperature']).reshape(-1, 1)

# Splitting the data into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15)


regr = LinearRegression()

regr.fit(X_train, y_train)
print(regr.score(X_test, y_test))
# Out:
# 0.82736982931933

# %%
y_pred = regr.predict(X_test)
plt.scatter(X_test, y_test, color ='y')
plt.plot(X_test, y_pred, color ='g')

plt.show()
# Data scatter of predicted values

# %% [markdown]
# **Temperature vs Solar Radiation (MJ/m2) Linear Regression**

# %%
df_binary = df[['Temperature', 'Solar Radiation (MJ/m2)']]
df['Solar Radiation (MJ/m2)'].replace('', np.nan)
df['Solar Radiation (MJ/m2)']=df['Solar Radiation (MJ/m2)'].fillna(df['Solar Radiation (MJ/m2)'].median())

# Taking only the selected two attributes from the dataset
df_binary.columns = ['Temp', 'Solar Rad']

df_binary.head()
# Out:
#    Temp  Solar Rad
# 0  -5.2        0.0
# 1  -5.5        0.0
# 2  -6.0        0.0
# 3  -6.2        0.0
# 4  -6.0        0.0

# %%
df_binary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Temp       8760 non-null   float64
#  1   Solar Rad  8760 non-null   float64
# dtypes: float64(2)
# memory usage: 137.0 KB

# %%
#plotting the Scatter plot to check relationship between SLength and SWidth
sns.lmplot(x ="Temp", y ="Solar Rad", data = df_binary, order = 2,ci=None) ##plot data wit overlaid rgression lines

# %%
X = np.array(df_binary['Temp']).reshape(-1, 1)
y = np.array(df_binary['Solar Rad']).reshape(-1, 1)

# Splitting the data into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)


regr = LinearRegression()

regr.fit(X_train, y_train)
print(regr.score(X_test, y_test))
# Out:
# 0.1269484074769578

# %%
y_pred = regr.predict(X_test)
plt.scatter(X_test, y_test, color ='g')
plt.plot(X_test, y_pred, color ='y')

plt.show()
# Data scatter of predicted values

# %% [markdown]
# **Humidity(%) vs Wind speed (m/s) Linear Regression**

# %%
df_binary = df[['Humidity(%)', 'Wind speed (m/s)']]

# Taking only the selected two attributes from the dataset
df_binary.columns = ['Humidity', 'Wind speed (m/s)']

df_binary.head()
# Out:
#    Humidity  Wind speed (m/s)
# 0        37               2.2
# 1        38               0.8
# 2        39               1.0
# 3        40               0.9
# 4        36               2.3

# %%
df_binary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Humidity          8760 non-null   int64
#  1   Wind speed (m/s)  8760 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 137.0 KB

# %%
#plotting the Scatter plot to check relationship between SLength and SWidth
sns.lmplot(x ="Humidity", y ="Wind speed (m/s)", data = df_binary, order = 2,ci=None) ##plot data wit overlaid rgression lines

# %%
X = np.array(df_binary['Humidity']).reshape(-1, 1)
y = np.array(df_binary['Wind speed (m/s)']).reshape(-1, 1)

# Splitting the data into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)


regr = LinearRegression()

regr.fit(X_train, y_train)
print(regr.score(X_test, y_test))
# Out:
# 0.1047771984112883

# %%
y_pred = regr.predict(X_test)
plt.scatter(X_test, y_test, color ='g')
plt.plot(X_test, y_pred, color ='b')

plt.show()
# Data scatter of predicted values

# %% [markdown]
# **Humidity (%) vs Visibility (10m) Linear Regression**

# %%
df_binary = df[['Humidity(%)', 'Visibility (10m)']]

# Taking only the selected two attributes from the dataset
df_binary.columns = ['Humidity', 'Visibility (10m)']

df_binary.head()
# Out:
#    Humidity  Visibility (10m)
# 0        37              2000
# 1        38              2000
# 2        39              2000
# 3        40              2000
# 4        36              2000

# %%
df_binary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Humidity          8760 non-null   int64
#  1   Visibility (10m)  8760 non-null   int64
# dtypes: int64(2)
# memory usage: 137.0 KB

# %%
#plotting the Scatter plot to check relationship between SLength and SWidth
sns.lmplot(x ="Humidity", y ="Visibility (10m)", data = df_binary, order = 2,ci=None) ##plot data wit overlaid rgression lines

# %%
X = np.array(df_binary['Humidity']).reshape(-1, 1)
y = np.array(df_binary['Visibility (10m)']).reshape(-1, 1)

# Splitting the data into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)


regr = LinearRegression()

regr.fit(X_train, y_train)
print(regr.score(X_test, y_test))
# Out:
# 0.31741578603064935

# %%
y_pred = regr.predict(X_test)
plt.scatter(X_test, y_test, color ='r')
plt.plot(X_test, y_pred, color ='b')

plt.show()
# Data scatter of predicted values

# %% [markdown]
# **Wind speed (m/s) vs Visibility (10m) Linear Regression**

# %%
df_binary = df[['Wind speed (m/s)', 'Visibility (10m)']]

# Taking only the selected two attributes from the dataset
df_binary.columns = ['Wind speed (m/s)', 'Visibility (10m)']

df_binary.head()
# Out:
#    Wind speed (m/s)  Visibility (10m)
# 0               2.2              2000
# 1               0.8              2000
# 2               1.0              2000
# 3               0.9              2000
# 4               2.3              2000

# %%
df_binary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Wind speed (m/s)  8760 non-null   float64
#  1   Visibility (10m)  8760 non-null   int64
# dtypes: float64(1), int64(1)
# memory usage: 137.0 KB

# %%
#plotting the Scatter plot to check relationship between SLength and SWidth
sns.lmplot(x ="Wind speed (m/s)", y ="Visibility (10m)", data = df_binary, order = 2,ci=None) ##plot data wit overlaid rgression lines

# %%
X = np.array(df_binary['Wind speed (m/s)']).reshape(-1, 1)
y = np.array(df_binary['Visibility (10m)']).reshape(-1, 1)

# Splitting the data into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.23)


regr = LinearRegression()

regr.fit(X_train, y_train)
print(regr.score(X_test, y_test))
# Out:
# 0.02076444113231235

# %%
y_pred = regr.predict(X_test)
plt.scatter(X_test, y_test, color ='b')
plt.plot(X_test, y_pred, color ='r')

plt.show()
# Data scatter of predicted values

# %% [markdown]
# **Logistic Regression** **y=Spring or Not Spring**

# %%
dataset = pd.read_csv('/content/SeoulBikeData - SeoulBikeData.csv',encoding='latin')

# %%
dataset.head()
# Out:
#          Date  Rented Bike Count  Hour  Temperature(è)  Humidity(%)  \
# 0  01/12/2017                254     0              -5.2           37
# 1  01/12/2017                204     1              -5.5           38
# 2  01/12/2017                173     2              -6.0           39
# 3  01/12/2017                107     3              -6.2           40
# 4  01/12/2017                 78     4              -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(è)  \
# 0               2.2              2000                       -17.6
# 1               0.8              2000                       -17.6
# 2               1.0              2000                       -17.7
# 3               0.9              2000                       -17.6
# 4               2.3              2000                       -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# ...

# %%
dataset['Seasons'] = dataset['Seasons'].replace('Winter', '0')
dataset['Seasons'] = dataset['Seasons'].replace('Autumn', '0')
dataset['Seasons'] = dataset['Seasons'].replace('Summer', '0')
dataset['Seasons'] = dataset['Seasons'].replace('Spring', '1.')

# %%
dataset['Seasons'] = dataset['Seasons'].astype(float)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        8760 non-null   object
#  1   Rented Bike Count           8760 non-null   int64
#  2   Hour                        8760 non-null   int64
#  3   Temperature(è)            8760 non-null   float64
#  4   Humidity(%)                 8760 non-null   int64
#  5   Wind speed (m/s)            8760 non-null   float64
#  6   Visibility (10m)            8760 non-null   int64
#  7   Dew point temperature(è)  8760 non-null   float64
#  8   Solar Radiation (MJ/m2)     8736 non-null   float64
#  9   Rainfall(mm)                8718 non-null   float64
#  10  Snowfall (cm)               8742 non-null   float64
#  11  Seasons                     8760 non-null   float64
#  12  Holiday                     8760 non-null   object
# ...

# %%
# input
x = dataset.iloc[:, 3].values

# output
y = dataset.iloc[:, 11].values

# %%
X = np.array(x).reshape(-1, 1)
Y = np.array(y).reshape(-1, 1)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.30, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
xtrain = sc_x.fit_transform(X_train)
xtest = sc_x.transform(X_test)

print (xtrain[0:10, :])
# Out:
# [[ 0.93803785]
#  [ 2.08972768]
#  [ 0.38722967]
#  [-0.93137173]
#  [ 1.18840521]
#  [ 1.35531678]
#  [ 1.4220814 ]
#  [ 0.75443512]
#  [-0.42229144]
#  [ 1.33028004]]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(xtrain, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(random_state=0)

# %%
y_pred = classifier.predict(xtest)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

print ("Confusion Matrix : \n", cm)
# Out:
# Confusion Matrix :
#  [[1968    0]
#  [ 660    0]]

# %%
from sklearn.metrics import accuracy_score
print ("Accuracy : ", accuracy_score(y_test, y_pred))
# Out:
# Accuracy :  0.7488584474885844

# %% [markdown]
# **Logistic Regression y=Winter or Not Winter**

# %%
dataset['Seasons'] = dataset['Seasons'].replace('Winter', '1')
dataset['Seasons'] = dataset['Seasons'].replace('Autumn', '0')
dataset['Seasons'] = dataset['Seasons'].replace('Summer', '0')
dataset['Seasons'] = dataset['Seasons'].replace('Spring', '0')

# %%
dataset['Seasons'] = dataset['Seasons'].astype(float)

# %%
# input
x = dataset.iloc[:, 5].values

# output
y = dataset.iloc[:, 13].values

# %%
X = np.array(x).reshape(-1, 1)
Y = np.array(y).reshape(-1, 1)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.30, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
xtrain = sc_x.fit_transform(X_train)
xtest = sc_x.transform(X_test)

print (xtrain[0:10, :])
# Out:
# [[-0.88644833]
#  [ 0.55227833]
#  [ 0.07270278]
#  [ 1.991005  ]
#  [-0.02321233]
#  [ 0.45636322]
#  [ 1.127769  ]
#  [-0.598703  ]
#  [-1.07827855]
#  [ 0.36044811]]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(xtrain, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(random_state=0)

# %%
y_pred = classifier.predict(xtest)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

print ("Confusion Matrix : \n", cm)
# Out:
# Confusion Matrix :
#  [[   0   97]
#  [   0 2531]]

# %%
from sklearn.metrics import accuracy_score
print ("Accuracy : ", accuracy_score(y_test, y_pred))
# Out:
# Accuracy :  0.963089802130898
